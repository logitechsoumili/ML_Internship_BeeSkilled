# %% [markdown]
# # 1. Load a dataset using Pandas and summarize basic stats (.info(), .describe()).

# %%
# !pip install kagglehub

import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = kagglehub.dataset_download("yasserh/titanic-dataset")

print("Dataset Path:", path)
# Out:
# Using Colab cache for faster access to the 'titanic-dataset' dataset.
# Dataset Path: /kaggle/input/titanic-dataset

# %%
import os

for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /kaggle/input/titanic-dataset/Titanic-Dataset.csv

# %%
df = pd.read_csv("/kaggle/input/titanic-dataset/Titanic-Dataset.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 2. Handle missing data using mean/median imputation.

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

# %%
df.drop("Cabin", axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # 3. Encode categorical variables using LabelEncoder & OneHotEncoder.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["Sex_Label"] = le.fit_transform(df["Sex"])

df[["Sex", "Sex_Label"]].head()
# Out:
#       Sex  Sex_Label
# 0    male          1
# 1  female          0
# 2  female          0
# 3  female          0
# 4    male          1

# %%
df = pd.get_dummies(
    df,
    columns=["Embarked"],
    prefix="Embarked"
)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Sex_Label  Embarked_C  Embarked_Q  \
# 0      0         A/5 21171   7.2500          1       False       False
# 1      0          PC 17599  71.2833          0        True       False
# 2      0  STON/O2. 3101282   7.9250          0       False       False
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_folder = "/content/drive/MyDrive/Titanic_Data_Cleaning_Project"

os.makedirs(project_folder, exist_ok=True)

print("Project folder ready.")
# Out:
# Project folder ready.

# %%
csv_path = "/content/drive/MyDrive/Titanic_Data_Cleaning_Project/titanic_cleaned.csv"

df.to_csv(csv_path, index=False)

print("CSV saved:", csv_path)
# Out:
# CSV saved: /content/drive/MyDrive/Titanic_Data_Cleaning_Project/titanic_cleaned.csv

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Age"], bins=30, kde=True)

plt.title("Age Distribution of Titanic Passengers")
plt.xlabel("Age")
plt.ylabel("Count")

png_path = "/content/drive/MyDrive/Titanic_Data_Cleaning_Project/age_distribution.png"

plt.savefig(png_path, bbox_inches="tight")

plt.show()

print("Plot saved:", png_path)
# Out:
# Plot saved: /content/drive/MyDrive/Titanic_Data_Cleaning_Project/age_distribution.png
